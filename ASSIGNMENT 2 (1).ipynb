# %%
import pandas as pd
import numpy as np
import re

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, classification_report

from textblob import TextBlob

# %%
print("Libraries loaded successfully")
# Out:
# Libraries loaded successfully

# %%
df = pd.read_csv("GooglePlay_Reviews.csv")
df.head()
# Out:
#       Reviewer Name          Review Date   Review Content
# 0      Shahzad Khan  2026-03-01 20:40:17            wow 😳
# 1          Alka Roy  2026-03-01 20:39:05             nice
# 2      Bhai098 Bhil  2026-03-01 20:38:44         nice app
# 3    Akshita Sharma  2026-03-01 20:38:31      really good
# 4  Mohamed Abdullah  2026-03-01 20:36:12  I love this app

# %%
df.columns
# Out:
# Index(['Reviewer Name', 'Review Date', 'Review Content'], dtype='str')

# %%
df.columns
# Out:
# Index(['Reviewer Name', 'Review Date', 'Review Content'], dtype='str')

# %%
df = df[['Review Content']]
df.dropna(inplace=True)

df.columns = ['review']
df.head()
# Out:
#             review
# 0            wow 😳
# 1             nice
# 2         nice app
# 3      really good
# 4  I love this app

# %%
import re

def clean_text(text):
    text = text.lower()
    text = re.sub(r'[^a-zA-Z]', ' ', text)
    return text

df['Clean_Text'] = df['review'].apply(clean_text)

# %%
from textblob import TextBlob

def get_sentiment(text):
    polarity = TextBlob(text).sentiment.polarity
    
    if polarity < 0:
        return 0
    elif polarity == 0:
        return 1
    else:
        return 2

df['Sentiment'] = df['Clean_Text'].apply(get_sentiment)

# %%
df.head()
# Out:
#             review       Clean_Text  Sentiment
# 0            wow 😳            wow            2
# 1             nice             nice          2
# 2         nice app         nice app          2
# 3      really good      really good          2
# 4  I love this app  i love this app          2

# %%
df['Sentiment'].value_counts()
# Out:
# Sentiment
# 2    63
# 1    33
# 0     4
# Name: count, dtype: int64

# %%
print("Total reviews:", len(df))
# Out:
# Total reviews: 100

# %%
# TextBlob is a lexicon-based method that is simple and fast.
# It does not require training data but may be less accurate.
# Machine learning methods are more accurate but require labeled data.
# In this dataset, TextBlob was used due to lack of rating labels.

# %% [markdown]
# Name: Aleeya Elisya
# Student ID: BIS01084269
#
# Discussion:
#
# This assignment used a lexicon-based method (TextBlob) for sentiment analysis.
# The strength of this method is that it is simple, fast, and does not require training data.
# However, its weakness is that it may not accurately capture context, sarcasm, or complex language.
#
# Machine learning models, such as Naive Bayes, are generally more accurate because they learn from labeled data.
# However, they require training data and more processing time.
#
# Overall, lexicon-based methods are easier to implement, while machine learning methods provide better performance.
